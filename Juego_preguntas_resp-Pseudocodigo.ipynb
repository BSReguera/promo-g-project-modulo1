# %% [markdown]
# <span style="font-family: Arial; font-size: 14px;">
#
# PROYECTO ADALAB
#
# # Preguntas y Respuestas
#
# - Reglas del Juego de "Preguntas y Respuestas de Geografía":
#
#     - El juego consiste en hacer preguntas de geografía y que el jugador adivine la respuesta correcta.
#
#     - Cada pregunta tiene una respuesta única y correcta.
#
#     - El jugador tiene un número limitado de intentos para responder correctamente a cada pregunta.
#
#     - El juego sigue hasta que el jugador responda incorrectamente 3 de veces o haya respondido 5 preguntas correctamente.
#
#
# # PROPUESTAS PSEUDOCÓDIGO
#
# - Opción de que los jugadores indiquen su nombre.
#
# - Tiene que responder a la vez. ??
#
# - Que la pregunta no se repita.
#
# - Lo haremos por rondas (2 preguntas) donde responda jugador 1 y después jugador 2. Gana el mejor de 3 rondas. Limitamos tiempo de respuesta a 15 segundos.
#
# - Se gana: aciertas 5
#
# - se pierde y se para el juego: si se fallan 3.
#
# - ¿Dar opciones de respuesta o que respondan a ciegas? ¿Qué código?
#
# - Vamos a dar tiempo a responder? ¿15 segundos? Se utilizaría libreria:'import time'/'time.time para registrar tiempo antes de responder y tras respuesta.
#
# - En caso de empate: ¿3 preguntas más por jugador? ¿mejor tiempo?
#
#
# # PISTAS (A REALIZAR)
#
#     1. Definir DICCIONARIOS (3 en este caso) con niveles diferentes de dificultan siendo:
#             1.1.NIVEL FACIL: 3 PREGUNTAS (preparar 8 preguntas por ejemplo: capitales básicas, mares y oceános, cosas obvias)
#             2.2. NIVEL MEDIO: 2  PREGUNTAS (ríos, montañas/picos)
#             3.3. NIVEL DIFICIL: 1 PREGUNTA pueblo, afluentes, densidades de población, altura longitud (cifras).
#         ***PREGUNTAS EXTRAS EN CASO DE DESEMPATE (5)
#
#     2. Crear función para seleccionar una pregunta aleatoria del diccionario. (import random)/ (random.choice)
#
#     3. Utiliza un bucle 'WHILE' para hacer preguntas de geografía.
#
#     4. Dentro del bucle, presenta la pregunta al jugador y 4 opciones de respuesta a seleccionar. (for/if/elif/else para opciones preguntas)
#         - Para ofrecer 4 respuestas debemos hacer varios diccionarios:
#         *** ejemplo: ronda 1= {Pregunta X{Respuesta a:-, b:-, c:-, d:-,-:p.correcta }}
#     5. Lleva un seguimiento del número de preguntas realizadas y el número de respuestas correctas. Utilizar .format()- 'f' para dar resultado de valores en el juego.
#
#     6. Determina las condiciones de victoria y derrota del juego y sal del bucle cuando se cumplan estas condiciones.
#     ***(fin juego si 3 preguntas incorrectas o 5 correctas)***
#         - En caso de empate: ¿3 preguntas más por jugador? ¿mejor tiempo?
#
# </span>
